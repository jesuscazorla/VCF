# %% [markdown]
# ## MPNG Encoding

# %%
from IPython.display import Video

# %%
# !pip install -r ../requirements.txt

# %% [markdown]
# ### Help about basic functionality

# %%
# !python ../src/MPNG.py -h

# %% [markdown]
# ### Help to encode

# %%
# !python ../src/MPNG.py encode -h

# %% [markdown]
# ### Encode default (remote) video

# %%
Video("http://www.hpca.ual.es/~vruiz/videos/mobile_352x288x30x420x300.mp4")

# %%
# !rm /tmp/encoded_*.png  # Necessary between consecutive experiments
# !python ../src/MPNG.py encode
# Out:
# main Namespace(debug=False, subparser_name='encode', input='http://www.hpca.ual.es/~vruiz/videos/mobile_352x288x30x420x300.mp4', output='/tmp/encoded', func=<function encode at 0x7f0cd9bbb560>)
# (INFO) main: input = http://www.hpca.ual.es/~vruiz/videos/mobile_352x288x30x420x300.mp4
# (INFO) main: output = /tmp/encoded
# (INFO) MPNG: Encoding http://www.hpca.ual.es/~vruiz/videos/mobile_352x288x30x420x300.mp4
# (INFO) MPNG: Generating frame /tmp/encoded_0000.png (352, 288) RGB in=103164 out=216228
# (INFO) MPNG: Generating frame /tmp/encoded_0001.png (352, 288) RGB in=72754 out=216501
# (INFO) MPNG: Generating frame /tmp/encoded_0002.png (352, 288) RGB in=70089 out=216543
# (INFO) MPNG: Generating frame /tmp/encoded_0003.png (352, 288) RGB in=69750 out=216220
# (INFO) MPNG: Generating frame /tmp/encoded_0004.png (352, 288) RGB in=69622 out=216922
# (INFO) MPNG: Generating frame /tmp/encoded_0005.png (352, 288) RGB in=69342 out=216816
# (INFO) MPNG: Generating frame /tmp/encoded_0006.png (352, 288) RGB in=69894 out=217039
# (INFO) MPNG: Generating frame /tmp/encoded_0007.png (352, 288) RGB in=69593 out=216856
# (INFO) MPNG: Generating frame /tmp/encoded_0008.png (352, 288) RGB in=70531 out=217095
# (INFO) MPNG: Generating frame /tmp/encoded_0009.png (352, 288) RGB in=69862 out=217095
# (INFO) MPNG: Generating frame /tmp/encoded_0010.png (352, 288) RGB in=70005 out=217214
# (INFO) MPNG: Generating frame /tmp/encoded_0011.png (352, 288) RGB in=70287 out=217547
# (INFO) MPNG: Generating frame /tmp/encoded_0012.png (352, 288) RGB in=69943 out=217441
# (INFO) MPNG: Generating frame /tmp/encoded_0013.png (352, 288) RGB in=70869 out=217581
# (INFO) MPNG: Generating frame /tmp/encoded_0014.png (352, 288) RGB in=70306 out=217453
# (INFO) MPNG: Generating frame /tmp/encoded_0015.png (352, 288) RGB in=70605 out=217538
# (INFO) MPNG: Generating frame /tmp/encoded_0016.png (352, 288) RGB in=70423 out=217908
# (INFO) MPNG: Generating frame /tmp/encoded_0017.png (352, 288) RGB in=70532 out=217748
# (INFO) MPNG: Generating frame /tmp/encoded_0018.png (352, 288) RGB in=70967 out=217994
# (INFO) MPNG: Generating frame /tmp/encoded_0019.png (352, 288) RGB in=70410 out=217745
# (INFO) MPNG: Generating frame /tmp/encoded_0020.png (352, 288) RGB in=70148 out=217816
# (INFO) MPNG: Generating frame /tmp/encoded_0021.png (352, 288) RGB in=70241 out=216955
# (INFO) MPNG: Generating frame /tmp/encoded_0022.png (352, 288) RGB in=70933 out=216875
# (INFO) MPNG: Generating frame /tmp/encoded_0023.png (352, 288) RGB in=70429 out=216455
# (INFO) MPNG: Generating frame /tmp/encoded_0024.png (352, 288) RGB in=70866 out=216780
# (INFO) MPNG: Generating frame /tmp/encoded_0025.png (352, 288) RGB in=70043 out=216109
# (INFO) MPNG: Generating frame /tmp/encoded_0026.png (352, 288) RGB in=70257 out=215781
# (INFO) MPNG: Generating frame /tmp/encoded_0027.png (352, 288) RGB in=69686 out=215617
# (INFO) MPNG: Generating frame /tmp/encoded_0028.png (352, 288) RGB in=70295 out=216068
# (INFO) MPNG: Generating frame /tmp/encoded_0029.png (352, 288) RGB in=69774 out=215520
# (INFO) MPNG: Generating frame /tmp/encoded_0030.png (352, 288) RGB in=70463 out=215539
# (INFO) MPNG: Generating frame /tmp/encoded_0031.png (352, 288) RGB in=69611 out=215361
# (INFO) MPNG: Generating frame /tmp/encoded_0032.png (352, 288) RGB in=69957 out=215693
# (INFO) MPNG: Generating frame /tmp/encoded_0033.png (352, 288) RGB in=69373 out=215776
# (INFO) MPNG: Generating frame /tmp/encoded_0034.png (352, 288) RGB in=69563 out=215770
# (INFO) MPNG: Generating frame /tmp/encoded_0035.png (352, 288) RGB in=69553 out=215744
# (INFO) MPNG: Generating frame /tmp/encoded_0036.png (352, 288) RGB in=70271 out=215724
# (INFO) MPNG: Generating frame /tmp/encoded_0037.png (352, 288) RGB in=69731 out=215657
# (INFO) MPNG: Generating frame /tmp/encoded_0038.png (352, 288) RGB in=70159 out=216050
# (INFO) MPNG: Generating frame /tmp/encoded_0039.png (352, 288) RGB in=70126 out=215791
# (INFO) MPNG: Generating frame /tmp/encoded_0040.png (352, 288) RGB in=70473 out=216000
# (INFO) MPNG: Generating frame /tmp/encoded_0041.png (352, 288) RGB in=70446 out=215418
# (INFO) MPNG: Generating frame /tmp/encoded_0042.png (352, 288) RGB in=70519 out=215606
# (INFO) MPNG: Generating frame /tmp/encoded_0043.png (352, 288) RGB in=70684 out=215445
# (INFO) MPNG: Generating frame /tmp/encoded_0044.png (352, 288) RGB in=70331 out=215538
# (INFO) MPNG: Generating frame /tmp/encoded_0045.png (352, 288) RGB in=70346 out=216037
# (INFO) MPNG: Generating frame /tmp/encoded_0046.png (352, 288) RGB in=69795 out=216448
# (INFO) MPNG: Generating frame /tmp/encoded_0047.png (352, 288) RGB in=68766 out=216681
# (INFO) MPNG: Generating frame /tmp/encoded_0048.png (352, 288) RGB in=68103 out=216820
# (INFO) MPNG: Generating frame /tmp/encoded_0049.png (352, 288) RGB in=68322 out=216728
# (INFO) MPNG: Generating frame /tmp/encoded_0050.png (352, 288) RGB in=68766 out=216877
# (INFO) MPNG: Generating frame /tmp/encoded_0051.png (352, 288) RGB in=68509 out=217173
# (INFO) MPNG: Generating frame /tmp/encoded_0052.png (352, 288) RGB in=68704 out=217216
# (INFO) MPNG: Generating frame /tmp/encoded_0053.png (352, 288) RGB in=68450 out=217132
# (INFO) MPNG: Generating frame /tmp/encoded_0054.png (352, 288) RGB in=68521 out=217366
# (INFO) MPNG: Generating frame /tmp/encoded_0055.png (352, 288) RGB in=70497 out=218299
# (INFO) MPNG: Generating frame /tmp/encoded_0056.png (352, 288) RGB in=70221 out=217970
# (INFO) MPNG: Generating frame /tmp/encoded_0057.png (352, 288) RGB in=70754 out=218247
# (INFO) MPNG: Generating frame /tmp/encoded_0058.png (352, 288) RGB in=70525 out=218450
# (INFO) MPNG: Generating frame /tmp/encoded_0059.png (352, 288) RGB in=70357 out=218286
# (INFO) MPNG: Generating frame /tmp/encoded_0060.png (352, 288) RGB in=71541 out=218760
# (INFO) MPNG: Generating frame /tmp/encoded_0061.png (352, 288) RGB in=71531 out=218725
# (INFO) MPNG: Generating frame /tmp/encoded_0062.png (352, 288) RGB in=70935 out=219162
# (INFO) MPNG: Generating frame /tmp/encoded_0063.png (352, 288) RGB in=71683 out=219455
# (INFO) MPNG: Generating frame /tmp/encoded_0064.png (352, 288) RGB in=71421 out=219652
# (INFO) MPNG: Generating frame /tmp/encoded_0065.png (352, 288) RGB in=71660 out=219526
# (INFO) MPNG: Generating frame /tmp/encoded_0066.png (352, 288) RGB in=71816 out=220021
# (INFO) MPNG: Generating frame /tmp/encoded_0067.png (352, 288) RGB in=72152 out=220116
# (INFO) MPNG: Generating frame /tmp/encoded_0068.png (352, 288) RGB in=71883 out=220454
# (INFO) MPNG: Generating frame /tmp/encoded_0069.png (352, 288) RGB in=72560 out=220597
# (INFO) MPNG: Generating frame /tmp/encoded_0070.png (352, 288) RGB in=72838 out=220853
# (INFO) MPNG: Generating frame /tmp/encoded_0071.png (352, 288) RGB in=72598 out=220898
# (INFO) MPNG: Generating frame /tmp/encoded_0072.png (352, 288) RGB in=72387 out=221131
# (INFO) MPNG: Generating frame /tmp/encoded_0073.png (352, 288) RGB in=72677 out=221206
# (INFO) MPNG: Generating frame /tmp/encoded_0074.png (352, 288) RGB in=72661 out=221127
# (INFO) MPNG: Generating frame /tmp/encoded_0075.png (352, 288) RGB in=72760 out=221277
# (INFO) MPNG: Generating frame /tmp/encoded_0076.png (352, 288) RGB in=72942 out=221402
# (INFO) MPNG: Generating frame /tmp/encoded_0077.png (352, 288) RGB in=72769 out=221977
# (INFO) MPNG: Generating frame /tmp/encoded_0078.png (352, 288) RGB in=72826 out=221440
# (INFO) MPNG: Generating frame /tmp/encoded_0079.png (352, 288) RGB in=73003 out=221427
# (INFO) MPNG: Generating frame /tmp/encoded_0080.png (352, 288) RGB in=72944 out=221543
# (INFO) MPNG: Generating frame /tmp/encoded_0081.png (352, 288) RGB in=72704 out=222023
# (INFO) MPNG: Generating frame /tmp/encoded_0082.png (352, 288) RGB in=72920 out=222240
# (INFO) MPNG: Generating frame /tmp/encoded_0083.png (352, 288) RGB in=73188 out=222346
# (INFO) MPNG: Generating frame /tmp/encoded_0084.png (352, 288) RGB in=72818 out=222728
# (INFO) MPNG: Generating frame /tmp/encoded_0085.png (352, 288) RGB in=73638 out=222721
# (INFO) MPNG: Generating frame /tmp/encoded_0086.png (352, 288) RGB in=73395 out=223467
# (INFO) MPNG: Generating frame /tmp/encoded_0087.png (352, 288) RGB in=73880 out=223132
# (INFO) MPNG: Generating frame /tmp/encoded_0088.png (352, 288) RGB in=73631 out=223451
# (INFO) MPNG: Generating frame /tmp/encoded_0089.png (352, 288) RGB in=73385 out=223804
# (INFO) MPNG: Generating frame /tmp/encoded_0090.png (352, 288) RGB in=73906 out=224194
# (INFO) MPNG: Generating frame /tmp/encoded_0091.png (352, 288) RGB in=73361 out=223837
# (INFO) MPNG: Generating frame /tmp/encoded_0092.png (352, 288) RGB in=73707 out=224108
# (INFO) MPNG: Generating frame /tmp/encoded_0093.png (352, 288) RGB in=73576 out=224086
# (INFO) MPNG: Generating frame /tmp/encoded_0094.png (352, 288) RGB in=73176 out=224842
# (INFO) MPNG: Generating frame /tmp/encoded_0095.png (352, 288) RGB in=73701 out=224828
# (INFO) MPNG: Generating frame /tmp/encoded_0096.png (352, 288) RGB in=73366 out=225054
# (INFO) MPNG: Generating frame /tmp/encoded_0097.png (352, 288) RGB in=74051 out=224825
# (INFO) MPNG: Generating frame /tmp/encoded_0098.png (352, 288) RGB in=73640 out=224482
# (INFO) MPNG: Generating frame /tmp/encoded_0099.png (352, 288) RGB in=73785 out=225005
# (INFO) MPNG: Generating frame /tmp/encoded_0100.png (352, 288) RGB in=73981 out=224922
# (INFO) MPNG: Generating frame /tmp/encoded_0101.png (352, 288) RGB in=73401 out=224709
# (INFO) MPNG: Generating frame /tmp/encoded_0102.png (352, 288) RGB in=73339 out=225293
# (INFO) MPNG: Generating frame /tmp/encoded_0103.png (352, 288) RGB in=73207 out=225371
# (INFO) MPNG: Generating frame /tmp/encoded_0104.png (352, 288) RGB in=73683 out=225444
# (INFO) MPNG: Generating frame /tmp/encoded_0105.png (352, 288) RGB in=73918 out=225596
# (INFO) MPNG: Generating frame /tmp/encoded_0106.png (352, 288) RGB in=73809 out=225405
# (INFO) MPNG: Generating frame /tmp/encoded_0107.png (352, 288) RGB in=74182 out=225166
# (INFO) MPNG: Generating frame /tmp/encoded_0108.png (352, 288) RGB in=73482 out=225923
# (INFO) MPNG: Generating frame /tmp/encoded_0109.png (352, 288) RGB in=74061 out=226570
# (INFO) MPNG: Generating frame /tmp/encoded_0110.png (352, 288) RGB in=73842 out=226166
# (INFO) MPNG: Generating frame /tmp/encoded_0111.png (352, 288) RGB in=74231 out=226486
# (INFO) MPNG: Generating frame /tmp/encoded_0112.png (352, 288) RGB in=74203 out=226923
# (INFO) MPNG: Generating frame /tmp/encoded_0113.png (352, 288) RGB in=74078 out=226657
# (INFO) MPNG: Generating frame /tmp/encoded_0114.png (352, 288) RGB in=74385 out=226883
# (INFO) MPNG: Generating frame /tmp/encoded_0115.png (352, 288) RGB in=73706 out=226634
# (INFO) MPNG: Generating frame /tmp/encoded_0116.png (352, 288) RGB in=73868 out=227023
# (INFO) MPNG: Generating frame /tmp/encoded_0117.png (352, 288) RGB in=73831 out=227014
# (INFO) MPNG: Generating frame /tmp/encoded_0118.png (352, 288) RGB in=74051 out=226802
# (INFO) MPNG: Generating frame /tmp/encoded_0119.png (352, 288) RGB in=73789 out=226320
# (INFO) MPNG: Generating frame /tmp/encoded_0120.png (352, 288) RGB in=73121 out=225802
# (INFO) MPNG: Generating frame /tmp/encoded_0121.png (352, 288) RGB in=73776 out=225959
# (INFO) MPNG: Generating frame /tmp/encoded_0122.png (352, 288) RGB in=73268 out=226082
# (INFO) MPNG: Generating frame /tmp/encoded_0123.png (352, 288) RGB in=72954 out=226232
# (INFO) MPNG: Generating frame /tmp/encoded_0124.png (352, 288) RGB in=73143 out=226497
# (INFO) MPNG: Generating frame /tmp/encoded_0125.png (352, 288) RGB in=73157 out=226825
# (INFO) MPNG: Generating frame /tmp/encoded_0126.png (352, 288) RGB in=73702 out=227004
# (INFO) MPNG: Generating frame /tmp/encoded_0127.png (352, 288) RGB in=72322 out=226440
# (INFO) MPNG: Generating frame /tmp/encoded_0128.png (352, 288) RGB in=72315 out=226537
# (INFO) MPNG: Generating frame /tmp/encoded_0129.png (352, 288) RGB in=72361 out=226381
# (INFO) MPNG: Generating frame /tmp/encoded_0130.png (352, 288) RGB in=72345 out=226916
# (INFO) MPNG: Generating frame /tmp/encoded_0131.png (352, 288) RGB in=72584 out=227156
# (INFO) MPNG: Generating frame /tmp/encoded_0132.png (352, 288) RGB in=72283 out=226733
# (INFO) MPNG: Generating frame /tmp/encoded_0133.png (352, 288) RGB in=73396 out=227178
# (INFO) MPNG: Generating frame /tmp/encoded_0134.png (352, 288) RGB in=72688 out=227445
# (INFO) MPNG: Generating frame /tmp/encoded_0135.png (352, 288) RGB in=72927 out=227887
# (INFO) MPNG: Generating frame /tmp/encoded_0136.png (352, 288) RGB in=72935 out=228087
# (INFO) MPNG: Generating frame /tmp/encoded_0137.png (352, 288) RGB in=72153 out=227941
# (INFO) MPNG: Generating frame /tmp/encoded_0138.png (352, 288) RGB in=73406 out=228513
# (INFO) MPNG: Generating frame /tmp/encoded_0139.png (352, 288) RGB in=73360 out=228130
# (INFO) MPNG: Generating frame /tmp/encoded_0140.png (352, 288) RGB in=73370 out=228460
# (INFO) MPNG: Generating frame /tmp/encoded_0141.png (352, 288) RGB in=74270 out=228837
# (INFO) MPNG: Generating frame /tmp/encoded_0142.png (352, 288) RGB in=73217 out=229033
# (INFO) MPNG: Generating frame /tmp/encoded_0143.png (352, 288) RGB in=74420 out=228962
# (INFO) MPNG: Generating frame /tmp/encoded_0144.png (352, 288) RGB in=73715 out=228650
# (INFO) MPNG: Generating frame /tmp/encoded_0145.png (352, 288) RGB in=73460 out=228581
# (INFO) MPNG: Generating frame /tmp/encoded_0146.png (352, 288) RGB in=74220 out=228756
# (INFO) MPNG: Generating frame /tmp/encoded_0147.png (352, 288) RGB in=73092 out=229009
# (INFO) MPNG: Generating frame /tmp/encoded_0148.png (352, 288) RGB in=74279 out=228923
# (INFO) MPNG: Generating frame /tmp/encoded_0149.png (352, 288) RGB in=73095 out=229069
# (INFO) MPNG: Generating frame /tmp/encoded_0150.png (352, 288) RGB in=74308 out=229510
# (INFO) MPNG: Generating frame /tmp/encoded_0151.png (352, 288) RGB in=74280 out=229240
# (INFO) MPNG: Generating frame /tmp/encoded_0152.png (352, 288) RGB in=74540 out=229401
# (INFO) MPNG: Generating frame /tmp/encoded_0153.png (352, 288) RGB in=74473 out=229646
# (INFO) MPNG: Generating frame /tmp/encoded_0154.png (352, 288) RGB in=74098 out=229562
# (INFO) MPNG: Generating frame /tmp/encoded_0155.png (352, 288) RGB in=75027 out=230136
# (INFO) MPNG: Generating frame /tmp/encoded_0156.png (352, 288) RGB in=73581 out=229541
# (INFO) MPNG: Generating frame /tmp/encoded_0157.png (352, 288) RGB in=75047 out=229953
# (INFO) MPNG: Generating frame /tmp/encoded_0158.png (352, 288) RGB in=73837 out=230267
# (INFO) MPNG: Generating frame /tmp/encoded_0159.png (352, 288) RGB in=72329 out=230223
# (INFO) MPNG: Generating frame /tmp/encoded_0160.png (352, 288) RGB in=71184 out=230115
# (INFO) MPNG: Generating frame /tmp/encoded_0161.png (352, 288) RGB in=69673 out=229915
# (INFO) MPNG: Generating frame /tmp/encoded_0162.png (352, 288) RGB in=68524 out=229909
# (INFO) MPNG: Generating frame /tmp/encoded_0163.png (352, 288) RGB in=68908 out=229587
# (INFO) MPNG: Generating frame /tmp/encoded_0164.png (352, 288) RGB in=68289 out=229766
# (INFO) MPNG: Generating frame /tmp/encoded_0165.png (352, 288) RGB in=69063 out=229816
# (INFO) MPNG: Generating frame /tmp/encoded_0166.png (352, 288) RGB in=67247 out=229731
# (INFO) MPNG: Generating frame /tmp/encoded_0167.png (352, 288) RGB in=66106 out=229409
# (INFO) MPNG: Generating frame /tmp/encoded_0168.png (352, 288) RGB in=65764 out=229386
# (INFO) MPNG: Generating frame /tmp/encoded_0169.png (352, 288) RGB in=66049 out=229715
# (INFO) MPNG: Generating frame /tmp/encoded_0170.png (352, 288) RGB in=66571 out=229821
# (INFO) MPNG: Generating frame /tmp/encoded_0171.png (352, 288) RGB in=66999 out=230071
# (INFO) MPNG: Generating frame /tmp/encoded_0172.png (352, 288) RGB in=66609 out=230123
# (INFO) MPNG: Generating frame /tmp/encoded_0173.png (352, 288) RGB in=66055 out=230184
# (INFO) MPNG: Generating frame /tmp/encoded_0174.png (352, 288) RGB in=65771 out=230083
# (INFO) MPNG: Generating frame /tmp/encoded_0175.png (352, 288) RGB in=63864 out=229745
# (INFO) MPNG: Generating frame /tmp/encoded_0176.png (352, 288) RGB in=64944 out=229894
# (INFO) MPNG: Generating frame /tmp/encoded_0177.png (352, 288) RGB in=63779 out=230112
# (INFO) MPNG: Generating frame /tmp/encoded_0178.png (352, 288) RGB in=63774 out=230171
# (INFO) MPNG: Generating frame /tmp/encoded_0179.png (352, 288) RGB in=63033 out=229593
# (INFO) MPNG: Generating frame /tmp/encoded_0180.png (352, 288) RGB in=64204 out=229995
# (INFO) MPNG: Generating frame /tmp/encoded_0181.png (352, 288) RGB in=65340 out=230295
# (INFO) MPNG: Generating frame /tmp/encoded_0182.png (352, 288) RGB in=61564 out=230483
# (INFO) MPNG: Generating frame /tmp/encoded_0183.png (352, 288) RGB in=57452 out=230219
# (INFO) MPNG: Generating frame /tmp/encoded_0184.png (352, 288) RGB in=63839 out=230250
# (INFO) MPNG: Generating frame /tmp/encoded_0185.png (352, 288) RGB in=62028 out=229966
# (INFO) MPNG: Generating frame /tmp/encoded_0186.png (352, 288) RGB in=59518 out=229805
# (INFO) MPNG: Generating frame /tmp/encoded_0187.png (352, 288) RGB in=63553 out=229699
# (INFO) MPNG: Generating frame /tmp/encoded_0188.png (352, 288) RGB in=64965 out=229921
# (INFO) MPNG: Generating frame /tmp/encoded_0189.png (352, 288) RGB in=62557 out=229744
# (INFO) MPNG: Generating frame /tmp/encoded_0190.png (352, 288) RGB in=65611 out=229809
# (INFO) MPNG: Generating frame /tmp/encoded_0191.png (352, 288) RGB in=66568 out=229903
# (INFO) MPNG: Generating frame /tmp/encoded_0192.png (352, 288) RGB in=67111 out=230398
# (INFO) MPNG: Generating frame /tmp/encoded_0193.png (352, 288) RGB in=66587 out=230276
# (INFO) MPNG: Generating frame /tmp/encoded_0194.png (352, 288) RGB in=66065 out=230252
# (INFO) MPNG: Generating frame /tmp/encoded_0195.png (352, 288) RGB in=66362 out=230443
# (INFO) MPNG: Generating frame /tmp/encoded_0196.png (352, 288) RGB in=66723 out=230236
# (INFO) MPNG: Generating frame /tmp/encoded_0197.png (352, 288) RGB in=65925 out=230163
# (INFO) MPNG: Generating frame /tmp/encoded_0198.png (352, 288) RGB in=64147 out=229948
# (INFO) MPNG: Generating frame /tmp/encoded_0199.png (352, 288) RGB in=64338 out=229502
# (INFO) MPNG: Generating frame /tmp/encoded_0200.png (352, 288) RGB in=66578 out=229322
# (INFO) MPNG: Generating frame /tmp/encoded_0201.png (352, 288) RGB in=66422 out=229102
# (INFO) MPNG: Generating frame /tmp/encoded_0202.png (352, 288) RGB in=67065 out=229043
# (INFO) MPNG: Generating frame /tmp/encoded_0203.png (352, 288) RGB in=68249 out=229352
# (INFO) MPNG: Generating frame /tmp/encoded_0204.png (352, 288) RGB in=66801 out=229319
# (INFO) MPNG: Generating frame /tmp/encoded_0205.png (352, 288) RGB in=65054 out=229393
# (INFO) MPNG: Generating frame /tmp/encoded_0206.png (352, 288) RGB in=66843 out=229544
# (INFO) MPNG: Generating frame /tmp/encoded_0207.png (352, 288) RGB in=68753 out=230129
# (INFO) MPNG: Generating frame /tmp/encoded_0208.png (352, 288) RGB in=69245 out=230040
# (INFO) MPNG: Generating frame /tmp/encoded_0209.png (352, 288) RGB in=68357 out=230230
# (INFO) MPNG: Generating frame /tmp/encoded_0210.png (352, 288) RGB in=69100 out=229772
# (INFO) MPNG: Generating frame /tmp/encoded_0211.png (352, 288) RGB in=69670 out=229911
# (INFO) MPNG: Generating frame /tmp/encoded_0212.png (352, 288) RGB in=69088 out=230240
# (INFO) MPNG: Generating frame /tmp/encoded_0213.png (352, 288) RGB in=69743 out=229947
# (INFO) MPNG: Generating frame /tmp/encoded_0214.png (352, 288) RGB in=70535 out=230247
# (INFO) MPNG: Generating frame /tmp/encoded_0215.png (352, 288) RGB in=69513 out=230315
# (INFO) MPNG: Generating frame /tmp/encoded_0216.png (352, 288) RGB in=69978 out=230405
# (INFO) MPNG: Generating frame /tmp/encoded_0217.png (352, 288) RGB in=71513 out=230058
# (INFO) MPNG: Generating frame /tmp/encoded_0218.png (352, 288) RGB in=71716 out=230267
# (INFO) MPNG: Generating frame /tmp/encoded_0219.png (352, 288) RGB in=71648 out=229708
# (INFO) MPNG: Generating frame /tmp/encoded_0220.png (352, 288) RGB in=70946 out=229937
# (INFO) MPNG: Generating frame /tmp/encoded_0221.png (352, 288) RGB in=71033 out=229536
# (INFO) MPNG: Generating frame /tmp/encoded_0222.png (352, 288) RGB in=71986 out=230096
# (INFO) MPNG: Generating frame /tmp/encoded_0223.png (352, 288) RGB in=72720 out=230300
# (INFO) MPNG: Generating frame /tmp/encoded_0224.png (352, 288) RGB in=72977 out=230528
# (INFO) MPNG: Generating frame /tmp/encoded_0225.png (352, 288) RGB in=72761 out=230065
# (INFO) MPNG: Generating frame /tmp/encoded_0226.png (352, 288) RGB in=73326 out=230890
# (INFO) MPNG: Generating frame /tmp/encoded_0227.png (352, 288) RGB in=71054 out=231001
# (INFO) MPNG: Generating frame /tmp/encoded_0228.png (352, 288) RGB in=68650 out=230680
# (INFO) MPNG: Generating frame /tmp/encoded_0229.png (352, 288) RGB in=68472 out=230543
# (INFO) MPNG: Generating frame /tmp/encoded_0230.png (352, 288) RGB in=65627 out=230458
# (INFO) MPNG: Generating frame /tmp/encoded_0231.png (352, 288) RGB in=65200 out=230266
# (INFO) MPNG: Generating frame /tmp/encoded_0232.png (352, 288) RGB in=65836 out=229871
# (INFO) MPNG: Generating frame /tmp/encoded_0233.png (352, 288) RGB in=65814 out=230044
# (INFO) MPNG: Generating frame /tmp/encoded_0234.png (352, 288) RGB in=64415 out=229979
# (INFO) MPNG: Generating frame /tmp/encoded_0235.png (352, 288) RGB in=64850 out=229949
# (INFO) MPNG: Generating frame /tmp/encoded_0236.png (352, 288) RGB in=64491 out=230028
# (INFO) MPNG: Generating frame /tmp/encoded_0237.png (352, 288) RGB in=64851 out=229983
# (INFO) MPNG: Generating frame /tmp/encoded_0238.png (352, 288) RGB in=65538 out=230750
# (INFO) MPNG: Generating frame /tmp/encoded_0239.png (352, 288) RGB in=66028 out=230312
# (INFO) MPNG: Generating frame /tmp/encoded_0240.png (352, 288) RGB in=65856 out=230293
# (INFO) MPNG: Generating frame /tmp/encoded_0241.png (352, 288) RGB in=66017 out=230099
# (INFO) MPNG: Generating frame /tmp/encoded_0242.png (352, 288) RGB in=67051 out=230828
# (INFO) MPNG: Generating frame /tmp/encoded_0243.png (352, 288) RGB in=66636 out=230992
# (INFO) MPNG: Generating frame /tmp/encoded_0244.png (352, 288) RGB in=65844 out=230079
# (INFO) MPNG: Generating frame /tmp/encoded_0245.png (352, 288) RGB in=66214 out=230025
# (INFO) MPNG: Generating frame /tmp/encoded_0246.png (352, 288) RGB in=66608 out=230084
# (INFO) MPNG: Generating frame /tmp/encoded_0247.png (352, 288) RGB in=65832 out=229636
# (INFO) MPNG: Generating frame /tmp/encoded_0248.png (352, 288) RGB in=64715 out=229598
# (INFO) MPNG: Generating frame /tmp/encoded_0249.png (352, 288) RGB in=65489 out=229746
# (INFO) MPNG: Generating frame /tmp/encoded_0250.png (352, 288) RGB in=111204 out=229844
# (INFO) MPNG: Generating frame /tmp/encoded_0251.png (352, 288) RGB in=66744 out=229346
# (INFO) MPNG: Generating frame /tmp/encoded_0252.png (352, 288) RGB in=65493 out=229391
# (INFO) MPNG: Generating frame /tmp/encoded_0253.png (352, 288) RGB in=64809 out=229264
# (INFO) MPNG: Generating frame /tmp/encoded_0254.png (352, 288) RGB in=65349 out=229106
# (INFO) MPNG: Generating frame /tmp/encoded_0255.png (352, 288) RGB in=66882 out=228190
# (INFO) MPNG: Generating frame /tmp/encoded_0256.png (352, 288) RGB in=67402 out=228441
# (INFO) MPNG: Generating frame /tmp/encoded_0257.png (352, 288) RGB in=66724 out=227829
# (INFO) MPNG: Generating frame /tmp/encoded_0258.png (352, 288) RGB in=66311 out=227967
# (INFO) MPNG: Generating frame /tmp/encoded_0259.png (352, 288) RGB in=65779 out=228499
# (INFO) MPNG: Generating frame /tmp/encoded_0260.png (352, 288) RGB in=64874 out=228909
# (INFO) MPNG: Generating frame /tmp/encoded_0261.png (352, 288) RGB in=64944 out=229035
# (INFO) MPNG: Generating frame /tmp/encoded_0262.png (352, 288) RGB in=65106 out=228456
# (INFO) MPNG: Generating frame /tmp/encoded_0263.png (352, 288) RGB in=65618 out=227919
# (INFO) MPNG: Generating frame /tmp/encoded_0264.png (352, 288) RGB in=66275 out=228097
# (INFO) MPNG: Generating frame /tmp/encoded_0265.png (352, 288) RGB in=62160 out=227595
# (INFO) MPNG: Generating frame /tmp/encoded_0266.png (352, 288) RGB in=58146 out=227550
# (INFO) MPNG: Generating frame /tmp/encoded_0267.png (352, 288) RGB in=61668 out=227654
# (INFO) MPNG: Generating frame /tmp/encoded_0268.png (352, 288) RGB in=64057 out=227496
# (INFO) MPNG: Generating frame /tmp/encoded_0269.png (352, 288) RGB in=63018 out=227451
# (INFO) MPNG: Generating frame /tmp/encoded_0270.png (352, 288) RGB in=63637 out=227406
# (INFO) MPNG: Generating frame /tmp/encoded_0271.png (352, 288) RGB in=65711 out=227130
# (INFO) MPNG: Generating frame /tmp/encoded_0272.png (352, 288) RGB in=66625 out=226999
# (INFO) MPNG: Generating frame /tmp/encoded_0273.png (352, 288) RGB in=66256 out=227446
# (INFO) MPNG: Generating frame /tmp/encoded_0274.png (352, 288) RGB in=63823 out=227790
# (INFO) MPNG: Generating frame /tmp/encoded_0275.png (352, 288) RGB in=63037 out=227812
# (INFO) MPNG: Generating frame /tmp/encoded_0276.png (352, 288) RGB in=63775 out=228249
# (INFO) MPNG: Generating frame /tmp/encoded_0277.png (352, 288) RGB in=64137 out=228212
# (INFO) MPNG: Generating frame /tmp/encoded_0278.png (352, 288) RGB in=60659 out=227612
# (INFO) MPNG: Generating frame /tmp/encoded_0279.png (352, 288) RGB in=57471 out=226701
# (INFO) MPNG: Generating frame /tmp/encoded_0280.png (352, 288) RGB in=63481 out=226613
# (INFO) MPNG: Generating frame /tmp/encoded_0281.png (352, 288) RGB in=65432 out=226362
# (INFO) MPNG: Generating frame /tmp/encoded_0282.png (352, 288) RGB in=63056 out=226676
# (INFO) MPNG: Generating frame /tmp/encoded_0283.png (352, 288) RGB in=62270 out=225900
# (INFO) MPNG: Generating frame /tmp/encoded_0284.png (352, 288) RGB in=63897 out=225658
# (INFO) MPNG: Generating frame /tmp/encoded_0285.png (352, 288) RGB in=63505 out=225708
# (INFO) MPNG: Generating frame /tmp/encoded_0286.png (352, 288) RGB in=63809 out=226087
# (INFO) MPNG: Generating frame /tmp/encoded_0287.png (352, 288) RGB in=64554 out=226376
# (INFO) MPNG: Generating frame /tmp/encoded_0288.png (352, 288) RGB in=64180 out=226618
# (INFO) MPNG: Generating frame /tmp/encoded_0289.png (352, 288) RGB in=62426 out=227046
# (INFO) MPNG: Generating frame /tmp/encoded_0290.png (352, 288) RGB in=59003 out=227486
# (INFO) MPNG: Generating frame /tmp/encoded_0291.png (352, 288) RGB in=61314 out=227563
# (INFO) MPNG: Generating frame /tmp/encoded_0292.png (352, 288) RGB in=62977 out=228223
# (INFO) MPNG: Generating frame /tmp/encoded_0293.png (352, 288) RGB in=64022 out=228230
# (INFO) MPNG: Generating frame /tmp/encoded_0294.png (352, 288) RGB in=63623 out=228606
# (INFO) MPNG: Generating frame /tmp/encoded_0295.png (352, 288) RGB in=62540 out=229161
# (INFO) MPNG: Generating frame /tmp/encoded_0296.png (352, 288) RGB in=62515 out=228704
# (INFO) MPNG: Generating frame /tmp/encoded_0297.png (352, 288) RGB in=63623 out=228445
# (INFO) MPNG: Generating frame /tmp/encoded_0298.png (352, 288) RGB in=64328 out=228477
# (INFO) MPNG: Generating frame /tmp/encoded_0299.png (352, 288) RGB in=62365 out=228538
# (INFO) entropy_video_coding: Total 20820817 bytes read
# (INFO) entropy_video_coding: Total 67622301 bytes written
# (INFO) entropy_video_coding: N_frames=300
# (INFO) entropy_video_coding: width=352
# (INFO) entropy_video_coding: height=288
# (INFO) entropy_video_coding: N_channels=3
# (INFO) entropy_video_coding: Encoding (output) rate = 17.78785274621212 bits/pixel

# %% [markdown]
# ### Help to decode

# %%
# !python ../src/MPNG.py decode -h

# %% [markdown]
# ### Default decoding

# %%
# !python ../src/MPNG.py decode
# Out:
# main Namespace(debug=False, subparser_name='decode', input='/tmp/encoded', output='/tmp/decoded.mp4', func=<function decode at 0x7f029cde7600>)
# (INFO) main: input = /tmp/encoded
# (INFO) main: output = /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 0 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 1 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 2 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 3 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 4 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 5 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 6 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 7 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 8 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 9 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 10 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 11 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 12 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 13 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 14 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 15 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 16 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 17 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 18 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 19 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 20 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 21 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 22 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 23 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 24 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 25 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 26 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 27 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 28 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 29 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 30 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 31 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 32 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 33 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 34 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 35 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 36 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 37 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 38 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 39 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 40 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 41 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 42 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 43 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 44 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 45 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 46 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 47 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 48 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 49 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 50 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 51 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 52 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 53 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 54 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 55 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 56 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 57 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 58 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 59 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 60 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 61 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 62 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 63 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 64 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 65 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 66 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 67 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 68 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 69 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 70 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 71 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 72 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 73 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 74 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 75 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 76 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 77 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 78 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 79 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 80 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 81 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 82 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 83 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 84 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 85 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 86 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 87 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 88 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 89 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 90 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 91 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 92 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 93 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 94 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 95 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 96 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 97 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 98 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 99 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 100 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 101 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 102 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 103 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 104 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 105 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 106 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 107 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 108 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 109 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 110 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 111 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 112 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 113 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 114 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 115 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 116 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 117 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 118 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 119 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 120 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 121 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 122 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 123 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 124 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 125 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 126 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 127 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 128 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 129 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 130 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 131 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 132 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 133 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 134 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 135 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 136 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 137 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 138 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 139 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 140 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 141 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 142 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 143 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 144 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 145 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 146 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 147 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 148 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 149 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 150 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 151 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 152 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 153 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 154 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 155 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 156 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 157 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 158 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 159 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 160 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 161 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 162 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 163 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 164 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 165 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 166 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 167 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 168 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 169 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 170 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 171 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 172 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 173 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 174 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 175 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 176 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 177 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 178 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 179 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 180 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 181 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 182 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 183 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 184 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 185 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 186 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 187 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 188 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 189 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 190 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 191 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 192 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 193 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 194 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 195 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 196 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 197 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 198 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 199 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 200 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 201 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 202 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 203 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 204 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 205 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 206 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 207 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 208 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 209 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 210 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 211 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 212 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 213 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 214 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 215 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 216 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 217 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 218 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 219 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 220 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 221 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 222 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 223 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 224 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 225 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 226 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 227 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 228 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 229 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 230 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 231 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 232 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 233 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 234 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 235 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 236 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 237 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 238 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 239 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 240 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 241 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 242 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 243 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 244 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 245 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 246 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 247 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 248 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 249 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 250 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 251 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 252 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 253 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 254 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 255 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 256 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 257 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 258 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 259 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 260 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 261 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 262 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 263 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 264 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 265 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 266 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 267 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 268 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 269 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 270 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 271 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 272 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 273 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 274 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 275 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 276 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 277 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 278 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 279 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 280 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 281 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 282 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 283 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 284 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 285 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 286 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 287 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 288 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 289 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 290 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 291 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 292 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 293 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 294 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 295 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 296 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 297 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 298 into /tmp/decoded.mp4
# (INFO) MPNG: Decoding frame 299 into /tmp/decoded.mp4
# (INFO) entropy_video_coding: Total 0 bytes read
# (INFO) entropy_video_coding: Total 0 bytes written
# (INFO) entropy_video_coding: N_frames=300
# (INFO) entropy_video_coding: width=352
# (INFO) entropy_video_coding: height=288
# (INFO) entropy_video_coding: N_channels=3
# (INFO) entropy_video_coding: original_file=http://www.hpca.ual.es/~vruiz/videos/mobile_352x288x30x420x300.mp4
# (INFO) entropy_video_coding: N_frames=300.0
# (INFO) entropy_video_coding: BPP=17.78785274621212
# (INFO) entropy_video_coding: Computing RD performance ...
# (INFO) entropy_video_coding: ...
# RMSE = 0.5584236478422733
# (INFO) entropy_video_coding: J = R + D = 18.346276394054392

# %%
# !mv /tmp/decoded.mp4 .

# %%
# !mplayer decoded.mp4
# Out:
# MPlayer UNKNOWN-12 (C) 2000-2023 MPlayer Team
# do_connect: could not connect to socket
# connect: No such file or directory
# Failed to open LIRC support. You will not be able to use your remote control.
#
# Playing decoded.mp4.
# libavformat version 59.27.100 (external)
# AVI file format detected.
# [aviheader] Video stream found, -vid 0
# AVI: No audio stream found -> no sound.
# VIDEO:  [H264]  352x288  24bpp  30.000 fps  40093.9 kbps (4894.3 kbyte/s)
# libva info: VA-API version 1.17.0
# libva info: Trying to open /usr/lib/x86_64-linux-gnu/dri/iHD_drv_video.so
# libva info: Found init function __vaDriverInit_1_17
# libva info: va_openDriver() returns 0
# ==========================================================================
# Opening video decoder: [ffmpeg] FFmpeg's libavcodec codec family
# libavcodec version 59.37.100 (external)
# Selected video codec: [ffh264] vfm: ffmpeg (FFmpeg H.264)
# ==========================================================================
# Clip info:
#  Software: Lavf61.1.100
# Load subtitles in ./
# Audio: no sound
# Starting playback...
# Could not find matching colorspace - retrying with -vf scale...
# Opening video filter: [scale]
# Movie-Aspect is undefined - no prescaling applied.
# [swscaler @ 0x7f74d1a99f20]bicubic scaler, from yuv444p to yuv420p using MMXEXT
# VO: [vdpau] 352x288 => 352x288 Planar YV12
# V:   1.7  53/ 53 30% 13%  0.0% 0 0 V:   0.1   5/  5 ??% ??% ??,?% 0 0 V:   0.2   8/  8 ??% ??% ??,?% 0 0 V:   0.3   9/  9 ??% ??% ??,?% 0 0 V:   0.3  11/ 11 ??% ??% ??,?% 0 0 V:   0.4  12/ 12 ??% ??% ??,?% 0 0 V:   0.4  14/ 14 ??% ??% ??,?% 0 0 V:   0.5  15/ 15 ??% ??% ??,?% 0 0 V:   0.5  17/ 17 26% 14%  0.0% 0 0 V:   0.6  18/ 18 26% 14%  0.0% 0 0 V:   0.6  20/ 20 27% 14%  0.0% 0 0 V:   0.7  22/ 22 28% 14%  0.0% 0 0 V:   0.7  23/ 23 28% 14%  0.0% 0 0 V:   0.8  25/ 25 29% 14%  0.0% 0 0 V:   0.8  26/ 26 29% 14%  0.0% 0 0 V:   0.9  28/ 28 28% 13%  0.0% 0 0 V:   0.9  29/ 29 28% 13%  0.0% 0 0 V:   1.0  31/ 31 29% 13%  0.0% 0 0 V:   1.0  32/ 32 29% 13%  0.0% 0 0 V:   1.1  34/ 34 29% 13%  0.0% 0 0 V:   1.1  35/ 35 30% 13%  0.0% 0 0 V:   1.2  37/ 37 30% 13%  0.0% 0 0 V:   1.3  39/ 39 30% 13%  0.0% 0 0 V:   1.3  40/ 40 30% 13%  0.0% 0 0 V:   1.4  42/ 42 31% 13%  0.0% 0 0 V:   1.4  43/ 43 31% 13%  0.0% 0 0 V:   1.5  45/ 45 30% 13%  0.0% 0 0 V:   1.5  46/ 46 30% 13%  0.0% 0 0 V:   1.6  48/ 48 30% 13%  0.0% 0 0 V:   1.6  49/ 49 30% 13%  0.0% 0 0 V:   1.7  51/ 51 30% 13%  0.0% 0 0 V:   1.7  52/ 52 30% 13%  0.0% 0 0
#
# Exiting... (Quit)

# %%
Video("decoded.mp4")
# Out:
# <video src="decoded.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
Video("video.mp4")

# %%
Video("../src/mobile_352x288x30x420x300.avi")

# %% [markdown]
# ### Encoding and decoding a local images

# %%
# !wget http://www.hpca.ual.es/~vruiz/images/Homer.png -O /tmp/Homer.png

# %%
# !python ../src/PNG.py encode -i /tmp/Homer.png -o /tmp/Homer.huf

# %%
# !python ../src/PNG.py decode -o /tmp/Homer_dec.png -i /tmp/Homer.huf

# %%
display(Image(filename="/tmp/Homer.png"))

# %%
Video("https://www.hpca.ual.es/~vruiz/videos/container_352x288x30x420x300.avi")
# Out:
# <video src="https://www.hpca.ual.es/~vruiz/videos/container_352x288x30x420x300.avi" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>
